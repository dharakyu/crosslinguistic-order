# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
from tqdm import tqdm
# Out:
# /Users/dharakyu/opt/anaconda3/envs/word-ordering/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
endangerment_vars_df = pd.read_csv('raw_corpus_data/language_endangerment/raw_data.csv')
endangerment_vars_df.columns
# Out:
# Index(['ISO', 'name', 'region', 'AES', 'EGIDS', 'L1_pop', 'L1_pop_prop',
#        'island', 'documentation', 'area', 'bordering_language_richness',
#        'bordering_language_richness_perkm', 'bordering_language_evenness',
#        'language_richness', 'threatened_languages',
#        'threatened_prop_languages', 'language_evenness', 'official_status',
#        'language_of_education', 'minority_education', 'education_spending',
#        'years_of_schooling', 'GDPpc', 'life_expectancy_60', 'urban_change',
#        'roads', 'pop_density', 'human_footprint', 'cropland',
#        'pop_density_change', 'footprint_change', 'cropland_change', 'pasture',
#        'pasture_change', 'built', 'built_change', 'GINI', 'growing_season',
#        'temperature', 'temperature_seasonality', 'rainfall_seasonality',
#        'threatened_species', 'threatened_prop_species', 'waterways',
#        'roughness', 'altitude_range', 'world_language', 'Arabic', 'Malay',
#        'English', 'French', 'Hindustani', 'Mandarin', 'Portuguese', 'Russian',
#        'Spanish', 'Western_Africa', 'Oceania', 'Europe', 'Southern_Asia',
#        'South_America', 'Northern_America', 'Africa', 'South.Eastern_Asia',
#        'Arab', 'Asia', 'Central_America', 'Australia_and_New_Zealand'],
#       dtype='object')

# %%
word_order_clics_counts_df = pd.read_csv('processed_data/word_order_clics_counts.csv')

mapping = {'Adjective-Noun': 1, 'No dominant order': 2, 'Noun-Adjective': 3}
word_order_clics_counts_df['value'] = word_order_clics_counts_df['description'].map(mapping)
word_order_clics_counts_df = word_order_clics_counts_df[word_order_clics_counts_df['description'] != 'Only internally-headed relative clauses']
word_order_clics_counts_df
# Out:
#      Unnamed: 0 wals code               name  value     description  \
# 0             0       abk             Abkhaz    3.0  Noun-Adjective
# 1             1       abv               Abui    3.0  Noun-Adjective
# 2             2       abu               Abun    3.0  Noun-Adjective
# 3             3       ace           Acehnese    3.0  Noun-Adjective
# 4             4       acg            Achagua    3.0  Noun-Adjective
# ..          ...       ...                ...    ...             ...
# 497         508       yko  Yukaghir (Kolyma)    1.0  Adjective-Noun
# 498         509       ytu  Yukaghir (Tundra)    1.0  Adjective-Noun
# 499         510       yuw        Yuwaalaraay    1.0  Adjective-Noun
# 500         511       zun               Zuni    3.0  Noun-Adjective
# 501         512       omi               Ömie    3.0  Noun-Adjective
#
#       latitude   longitude                      genus                 family  \
# 0    43.083333   41.000000        Northwest Caucasian    Northwest Caucasian
# 1    -8.250000  124.666667                Alor-Pantar  Greater West Bomberai
# 2    -0.500000  132.500000                       Abun                   Abun
# 3     5.500000   95.500000            Malayo-Sumbawan           Austronesian
# 4     4.416667  -72.250000            Japura-Colombia               Arawakan
# ..         ...         ...                        ...                    ...
# 497  65.750000  150.833333                   Yukaghir               Yukaghir
# 498  69.000000  155.000000                   Yukaghir               Yukaghir
# 499 -29.500000  148.000000  Southeastern Pama-Nyungan           Pama-Nyungan
# 500  35.083333 -108.833333                       Zuni                   Zuni
# 501  -9.050000  148.083333                   Koiarian       Trans-New Guinea
#
#            area  ... Country_ID  \
# 0    Word Order  ...         GE
# 1    Word Order  ...         ID
# 2    Word Order  ...         ID
# 3    Word Order  ...         ID
# 4    Word Order  ...         CO
# ..          ...  ...        ...
# 497  Word Order  ...         RU
# 498  Word Order  ...         RU
# 499  Word Order  ...         AU
# 500  Word Order  ...         US
# 501  Word Order  ...         PG
#
#                                                 Source         dataset_ID  \
# 0    Bybee-et-al-1994 Gecadze-1979 Hewitt-1979 Hewi...              diacl
# 1                                      Kratochvil-2007          lexirumah
# 2         Berry-1995a Berry-1995b Berry-and-Berry-1999  transnewguineaorg
# 3    Aboe-Bakar-et-al-1985 Cowan-1981 Durie-1985 Du...              diacl
# 4    Aikhenvald-2007b Huber-and-Reed-1992 Melendez-...     hubercolumbian
# ..                                                 ...                ...
# 497  Maslova-1999 Maslova-2003a Nikolaeva-and-Xelim...       northeuralex
# 498     Krejnovich-1958 Krejnovich-1968c Maslova-2003b       northeuralex
# 499                         Mushin-1995 Williams-1980a          bowernpny
# 500  Bunzel-1933-1938 Bybee-et-al-1994 Cook-1975 Mi...                ids
# 501                              Austing-and-Upia-1975  transnewguineaorg
#
#                variety    Macroarea_y           Family_y  \
# 0               Abkhaz        Eurasia       Abkhaz-Adyge
# 1     Abui, Takalelang      Papunesia  Timor-Alor-Pantar
# 2                 Abun      Papunesia               Abun
# 3             Acehnese        Eurasia       Austronesian
# 4              Achagua  South America           Arawakan
# ..                 ...            ...                ...
# 497  Southern Yukaghir        Eurasia           Yukaghir
# 498  Northern Yukaghir        Eurasia           Yukaghir
# 499         Gamilaraay      Australia       Pama-Nyungan
# 500               Zuni  North America               Zuni
# 501               Ömie      Papunesia           Koiarian
#
#     num_unique_noun_words num_unique_noun_concepts num_unique_adj_words  \
# 0                     594                      502                  152
# 1                    1350                      327                  288
# 2                      95                       26                    6
# 3                      88                       89                    0
# 4                     187                      157                   56
# ..                    ...                      ...                  ...
# 497                   304                      299                   90
# 498                   372                      394                   88
# 499                   229                      171                   55
# 500                   498                      499                   90
# 501                    71                       67                   11
#
#     num_unique_adj_concepts
# 0                       100
# 1                        73
# 2                         2
# 3                         0
# 4                        32
# ..                      ...
# 497                      79
# 498                      85
# 499                      41
# 500                      94
# 501                       9
#
# [501 rows x 34 columns]

# %%
full_df = pd.merge(endangerment_vars_df, word_order_clics_counts_df, left_on='ISO', right_on='ISO639P3code')
full_df.to_csv('processed_data/language_endangerment.csv')

# %%
full_df
# Out:
#      ISO             name_x                     region             AES EGIDS  \
# 0    abk          Abkhazian                       Arab      threatened     2
# 1    abt            Ambulas                    Oceania      threatened     5
# 2    abz               Abui         South-Eastern Asia        shifting    6a
# 3    aca            Achagua              South America        shifting    6b
# 4    ace           Acehnese         South-Eastern Asia      threatened    6b
# ..   ...                ...                        ...             ...   ...
# 470  yux  Southern Yukaghir                     Europe  nearly extinct    8b
# 471  ywt      Xishanba Lalo                       Asia      threatened     7
# 472  zga              Kinga                     Africa  not endangered    6a
# 473  zmu           Muruwari  Australia and New Zealand  nearly extinct    10
# 474  zun               Zuni           Northern America        shifting    6b
#
#       L1_pop   L1_pop_prop  island documentation        area_x  ...  \
# 0     105000   3363.641012       0      detailed   1847.401115  ...
# 1      44000   1552.650420       0      detailed   1154.190211  ...
# 2      16000    215.533744       1      detailed    627.239851  ...
# 3        250     41.038933       0      detailed   3413.503013  ...
# 4    3500000  35411.014220       0      detailed  17655.564140  ...
# ..       ...           ...     ...           ...           ...  ...
# 470      370  12330.741540       0      detailed   3648.952815  ...
# 471   213000   1773.015389       0      detailed  15267.429170  ...
# 472   140000   2198.705850       0      detailed   2079.928842  ...
# 473        0      0.000000       0      detailed  60449.858810  ...
# 474     9650   2169.734849       0      detailed   1840.685062  ...
#
#      Country_ID                                             Source  \
# 0            GE  Bybee-et-al-1994 Gecadze-1979 Hewitt-1979 Hewi...
# 1            PG             Laycock-1965a Nichols-1992 Wilson-1980
# 2            ID                                    Kratochvil-2007
# 3            CO  Aikhenvald-2007b Huber-and-Reed-1992 Melendez-...
# 4            ID  Aboe-Bakar-et-al-1985 Cowan-1981 Durie-1985 Du...
# ..          ...                                                ...
# 470          RU  Maslova-1999 Maslova-2003a Nikolaeva-and-Xelim...
# 471          CN                                     Bjorverud-1998
# 472          TZ                                         Wolff-1905
# 473          AU                 Mushin-1995 Oates-1988 Trefry-1971
# 474          US  Bunzel-1933-1938 Bybee-et-al-1994 Cook-1975 Mi...
#
#             dataset_ID            variety    Macroarea_y           Family_y  \
# 0                diacl             Abkhaz        Eurasia       Abkhaz-Adyge
# 1    transnewguineaorg            Ambulas      Papunesia                Ndu
# 2            lexirumah   Abui, Takalelang      Papunesia  Timor-Alor-Pantar
# 3       hubercolumbian            Achagua  South America           Arawakan
# 4                diacl           Acehnese        Eurasia       Austronesian
# ..                 ...                ...            ...                ...
# 470       northeuralex  Southern Yukaghir        Eurasia           Yukaghir
# 471              suntb       Yi (Nanjian)        Eurasia       Sino-Tibetan
# 472                tls              Kinga         Africa     Atlantic-Congo
# 473          bowernpny           Muruwari      Australia       Pama-Nyungan
# 474                ids               Zuni  North America               Zuni
#
#      num_unique_noun_words  num_unique_noun_concepts  num_unique_adj_words  \
# 0                      594                       502                   152
# 1                       53                        40                     5
# 2                     1350                       327                   288
# 3                      187                       157                    56
# 4                       88                        89                     0
# ..                     ...                       ...                   ...
# 470                    304                       299                    90
# 471                    890                       620                   192
# 472                    365                       316                    52
# 473                    163                       167                    38
# 474                    498                       499                    90
#
#      num_unique_adj_concepts
# 0                        100
# 1                          5
# 2                         73
# 3                         32
# 4                          0
# ..                       ...
# 470                       79
# 471                      123
# 472                       37
# 473                       38
# 474                       94
#
# [475 rows x 102 columns]
