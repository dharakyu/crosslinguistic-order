# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# ## Merge the language endangerment data with the other data

# %%
endangerment_vars_df = pd.read_csv('raw_corpus_data/language_endangerment/raw_data.csv')
endangerment_vars_df.columns
# Out:
# Index(['ISO', 'name', 'region', 'AES', 'EGIDS', 'L1_pop', 'L1_pop_prop',
#        'island', 'documentation', 'area', 'bordering_language_richness',
#        'bordering_language_richness_perkm', 'bordering_language_evenness',
#        'language_richness', 'threatened_languages',
#        'threatened_prop_languages', 'language_evenness', 'official_status',
#        'language_of_education', 'minority_education', 'education_spending',
#        'years_of_schooling', 'GDPpc', 'life_expectancy_60', 'urban_change',
#        'roads', 'pop_density', 'human_footprint', 'cropland',
#        'pop_density_change', 'footprint_change', 'cropland_change', 'pasture',
#        'pasture_change', 'built', 'built_change', 'GINI', 'growing_season',
#        'temperature', 'temperature_seasonality', 'rainfall_seasonality',
#        'threatened_species', 'threatened_prop_species', 'waterways',
#        'roughness', 'altitude_range', 'world_language', 'Arabic', 'Malay',
#        'English', 'French', 'Hindustani', 'Mandarin', 'Portuguese', 'Russian',
#        'Spanish', 'Western_Africa', 'Oceania', 'Europe', 'Southern_Asia',
#        'South_America', 'Northern_America', 'Africa', 'South.Eastern_Asia',
#        'Arab', 'Asia', 'Central_America', 'Australia_and_New_Zealand'],
#       dtype='object')

# %%
word_order_clics_counts_df = pd.read_csv('processed_data/word_order_clics_counts_v2.csv').drop(columns=['Unnamed: 0'], axis=1)

mapping = {'Adjective-Noun': 1, 'No dominant order': 2, 'Noun-Adjective': 3}
word_order_clics_counts_df['adj_noun_order_coding'] = word_order_clics_counts_df['adj_noun_order'].map(mapping)
word_order_clics_counts_df = word_order_clics_counts_df[word_order_clics_counts_df['adj_noun_order'] != 'Only internally-headed relative clauses']
word_order_clics_counts_df
# Out:
#     wals code               name  OV_order_coded           OV_order  \
# 0         abk             Abkhaz               1                 OV
# 1         abv               Abui               1                 OV
# 2         abu               Abun               2                 VO
# 3         ace           Acehnese               3  No dominant order
# 4         acg            Achagua               2                 VO
# ..        ...                ...             ...                ...
# 431       ycn             Yucuna               2                 VO
# 432       yko  Yukaghir (Kolyma)               1                 OV
# 433       ytu  Yukaghir (Tundra)               1                 OV
# 434       yuw        Yuwaalaraay               1                 OV
# 435       zun               Zuni               1                 OV
#
#       latitude   longitude                      genus                 family  \
# 0    43.083333   41.000000        Northwest Caucasian    Northwest Caucasian
# 1    -8.250000  124.666667                Alor-Pantar  Greater West Bomberai
# 2    -0.500000  132.500000                       Abun                   Abun
# 3     5.500000   95.500000            Malayo-Sumbawan           Austronesian
# 4     4.416667  -72.250000            Japura-Colombia               Arawakan
# ..         ...         ...                        ...                    ...
# 431  -0.750000  -71.000000            Japura-Colombia               Arawakan
# 432  65.750000  150.833333                   Yukaghir               Yukaghir
# 433  69.000000  155.000000                   Yukaghir               Yukaghir
# 434 -29.500000  148.000000  Southeastern Pama-Nyungan           Pama-Nyungan
# 435  35.083333 -108.833333                       Zuni                   Zuni
#
#            area             name_x  ...            variety    Macroarea_y  \
# 0    Word Order             Abkhaz  ...             Abkhaz        Eurasia
# 1    Word Order               Abui  ...   Abui, Takalelang      Papunesia
# 2    Word Order               Abun  ...               Abun      Papunesia
# 3    Word Order           Acehnese  ...           Acehnese        Eurasia
# 4    Word Order            Achagua  ...            Achagua  South America
# ..          ...                ...  ...                ...            ...
# 431  Word Order             Yucuna  ...             Yucuna  South America
# 432  Word Order  Yukaghir (Kolyma)  ...  Southern Yukaghir        Eurasia
# 433  Word Order  Yukaghir (Tundra)  ...  Northern Yukaghir        Eurasia
# 434  Word Order        Yuwaalaraay  ...         Gamilaraay      Australia
# 435  Word Order               Zuni  ...               Zuni  North America
#
#               Family_y  num_unique_noun_words num_unique_noun_concepts  \
# 0         Abkhaz-Adyge                    594                      502
# 1    Timor-Alor-Pantar                   1350                      327
# 2                 Abun                     95                       26
# 3         Austronesian                     88                       89
# 4             Arawakan                    187                      157
# ..                 ...                    ...                      ...
# 431           Arawakan                    251                      217
# 432           Yukaghir                    304                      299
# 433           Yukaghir                    372                      394
# 434       Pama-Nyungan                    229                      171
# 435               Zuni                    498                      499
#
#     mean_noun_word_len num_unique_adj_words num_unique_adj_concepts  \
# 0             7.088785                  152                     100
# 1             6.498814                  288                      73
# 2             3.980769                    6                       2
# 3             5.662921                    0                       0
# 4             6.137755                   56                      32
# ..                 ...                  ...                     ...
# 431           7.643678                   43                      38
# 432           6.448680                   90                      79
# 433           7.889412                   88                      85
# 434           6.091176                   55                      41
# 435           8.037906                   90                      94
#
#      mean_adj_word_len adj_noun_order_coding
# 0             7.765823                   3.0
# 1             6.213235                   3.0
# 2             2.875000                   3.0
# 3                  NaN                   3.0
# 4             6.857143                   3.0
# ..                 ...                   ...
# 431           8.681818                   1.0
# 432           6.525253                   1.0
# 433           8.715789                   1.0
# 434           6.560976                   1.0
# 435           7.653061                   3.0
#
# [435 rows x 52 columns]

# %%
full_df = pd.merge(endangerment_vars_df, word_order_clics_counts_df, left_on='ISO', right_on='ISO639P3code')
full_df.to_csv('processed_data/language_endangerment_v2.csv')
# Out:
# /var/folders/wh/tk6j12kd7jq5djbxfn93wjdm0000gn/T/ipykernel_32863/2568545452.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'area_y', 'name_y'} in the result is deprecated and will raise a MergeError in a future version.
#   full_df = pd.merge(endangerment_vars_df, word_order_clics_counts_df, left_on='ISO', right_on='ISO639P3code')

# %%
full_df
# Out:
#      ISO             name_x                     region             AES EGIDS  \
# 0    abk          Abkhazian                       Arab      threatened     2
# 1    abt            Ambulas                    Oceania      threatened     5
# 2    abz               Abui         South-Eastern Asia        shifting    6a
# 3    aca            Achagua              South America        shifting    6b
# 4    ace           Acehnese         South-Eastern Asia      threatened    6b
# ..   ...                ...                        ...             ...   ...
# 407  yux  Southern Yukaghir                     Europe  nearly extinct    8b
# 408  ywt      Xishanba Lalo                       Asia      threatened     7
# 409  zga              Kinga                     Africa  not endangered    6a
# 410  zmu           Muruwari  Australia and New Zealand  nearly extinct    10
# 411  zun               Zuni           Northern America        shifting    6b
#
#       L1_pop   L1_pop_prop  island documentation        area_x  ...  \
# 0     105000   3363.641012       0      detailed   1847.401115  ...
# 1      44000   1552.650420       0      detailed   1154.190211  ...
# 2      16000    215.533744       1      detailed    627.239851  ...
# 3        250     41.038933       0      detailed   3413.503013  ...
# 4    3500000  35411.014220       0      detailed  17655.564140  ...
# ..       ...           ...     ...           ...           ...  ...
# 407      370  12330.741540       0      detailed   3648.952815  ...
# 408   213000   1773.015389       0      detailed  15267.429170  ...
# 409   140000   2198.705850       0      detailed   2079.928842  ...
# 410        0      0.000000       0      detailed  60449.858810  ...
# 411     9650   2169.734849       0      detailed   1840.685062  ...
#
#                variety    Macroarea_y           Family_y  \
# 0               Abkhaz        Eurasia       Abkhaz-Adyge
# 1              Ambulas      Papunesia                Ndu
# 2     Abui, Takalelang      Papunesia  Timor-Alor-Pantar
# 3              Achagua  South America           Arawakan
# 4             Acehnese        Eurasia       Austronesian
# ..                 ...            ...                ...
# 407  Southern Yukaghir        Eurasia           Yukaghir
# 408       Yi (Nanjian)        Eurasia       Sino-Tibetan
# 409              Kinga         Africa     Atlantic-Congo
# 410           Muruwari      Australia       Pama-Nyungan
# 411               Zuni  North America               Zuni
#
#      num_unique_noun_words  num_unique_noun_concepts  mean_noun_word_len  \
# 0                      594                       502            7.088785
# 1                       53                        40            3.827586
# 2                     1350                       327            6.498814
# 3                      187                       157            6.137755
# 4                       88                        89            5.662921
# ..                     ...                       ...                 ...
# 407                    304                       299            6.448680
# 408                    890                       620            9.386431
# 409                    365                       316            7.362720
# 410                    163                       167            6.335329
# 411                    498                       499            8.037906
#
#      num_unique_adj_words  num_unique_adj_concepts  mean_adj_word_len  \
# 0                     152                      100           7.765823
# 1                       5                        5           4.200000
# 2                     288                       73           6.213235
# 3                      56                       32           6.857143
# 4                       0                        0                NaN
# ..                    ...                      ...                ...
# 407                    90                       79           6.525253
# 408                   192                      123           6.144144
# 409                    52                       37           6.980769
# 410                    38                       38           6.947368
# 411                    90                       94           7.653061
#
#      adj_noun_order_coding
# 0                      3.0
# 1                      1.0
# 2                      3.0
# 3                      3.0
# 4                      3.0
# ..                     ...
# 407                    1.0
# 408                    3.0
# 409                    3.0
# 410                    1.0
# 411                    3.0
#
# [412 rows x 120 columns]
